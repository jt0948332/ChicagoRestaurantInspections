# %%
import pandas as pd
import requests
import pymongo
from sqlalchemy import create_engine



url = 'https://data.cityofchicago.org/api/views/5udb-dr6f/rows.json?accessType=DOWNLOAD'
r= requests.get(url).json()

# %%
df = pd.DataFrame(r['data'])
df = df.drop(df.columns[[0, 1, 2, 3, 5, 7]], axis=1, inplace=False)
df =df.dropna(axis=1, how='all', thresh=None, subset=None, inplace=False)
df.rename(columns={8:'Name',9:'DBA',10:'identifier', 11:'Type',12:'Risk', 13:'Street',14:'City', 15:'State', 16:'Zip', 17:'Date',18:'Inspection',19:'Success',20:'Description', 21:'lat', 22:'lng'}, inplace=True)
df['Date'] = pd.to_datetime(df['Date']).apply(lambda x:x.strftime('%m/%d/%Y'))
df.head(5)
# Out:
#                          Name                         DBA identifier  \
# 0          DANA HOTEL AND SPA            PORTSMITH/APOGEE    1884390
# 1  GORILLA SUSHI LOGAN SQUARE  GORILLA SUSHI LOGAN SQUARE    2543141
# 2    PICNIC WINE & PROVISIONS    PICNIC WINE & PROVISIONS    2658904
# 3    PICNIC WINE & PROVISIONS    PICNIC WINE & PROVISIONS    2636701
# 4    PICNIC WINE & PROVISIONS    PICNIC WINE & PROVISIONS    2636702
#
#          Type             Risk                 Street     City State    Zip  \
# 0  Restaurant    Risk 1 (High)           2 W ERIE ST   CHICAGO    IL  60654
# 1  Restaurant    Risk 1 (High)  2735 N MILWAUKEE AVE   CHICAGO    IL  60647
# 2  Restaurant  Risk 2 (Medium)    7301 N SHERIDAN RD   CHICAGO    IL  60626
# 3  Restaurant  Risk 2 (Medium)    7301 N SHERIDAN RD   CHICAGO    IL  60626
# 4  Restaurant  Risk 2 (Medium)    7301 N SHERIDAN RD   CHICAGO    IL  60626
#
#          Date             Inspection Success  \
# 0  06/07/2019  Canvass Re-Inspection    Pass
# 1  06/06/2019                Canvass    Fail
# 2  06/06/2019                License    Fail
# 3  06/06/2019                License    Fail
# 4  06/06/2019                License    Fail
#
#                                          Description                lat  \
# 0  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  41.89418045475969
# 1  3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL E...  41.93096908810037
# 2                                               None   42.0140411322766
# 3                                               None   42.0140411322766
# 4                                               None   42.0140411322766
#
#                   lng
# 0  -87.62821812644587
# 1  -87.71028632230771
# 2   -87.6639709089456
# 3   -87.6639709089456
# 4   -87.6639709089456

# %%
###########Method 1 MONGO DB   #################

#insert into Mongo
#REMEMBER TO START MONGOD in your bash!!!!!!!!
conn = 'mongodb://localhost:27017'
client=pymongo.MongoClient(conn)
#define DB and collection/table to work with
db = client.ChicagoRest
#convert DataFrame to JSON format for insert
#Load all dataframes
records = json.loads(df.to_json(orient='records'))
db.CompanyData.insert_many(records)

# %%
#sqlite
connection_string = "sqlite:///ChicagoRestaurants.sqlite"
engine = create_engine(connection_string)
#list tables names- if you want
#engine.table_names()

####Create the database to match our columns in our dataframe####
#Name	DBA	ID	Type	Risk	Street	City	State	Zip	Date	Inspection	Success	Description	lat	lng


##############IMPORTANT###############################
########### hash out this after creating as it will give an error stating the DB already exists after running the first time ####
####apparently the line below is not needed to create the sql lite.. if unhash it creates another table in the db
engine.execute("CREATE TABLE RestaurantData(id INT PRIMARY KEY, Name TEXT, DBA TEXT, identifier TEXT, Type TEXT, Risk TEXT, Street TEXT, City TEXT, State TEXT, Zip TEXT, Date TEXT, Inspection TEXT, Success TEXT, Description TEXT, Lat Int, Lng Int);")
#engine.execute("CREATE TABLE RestaurantData(Name TEXT, DBA TEXT, identifier TEXT, Type TEXT, Risk TEXT, Street TEXT, City TEXT, State TEXT, Zip TEXT, Date TEXT, Inspection TEXT, Success TEXT, Description TEXT, Lat Int, Lng Int);")

################################################################################################################

####### PLUG that data into SQLITE#####
df.to_sql(name="RestaurantData", con=engine, if_exists="append", index=False)
#####SHOW ME THE MONEY#####
pd.read_sql_query("SELECT * FROM RestaurantData",con=engine).head()
# Out:
#      id                        Name                         DBA identifier  \
# 0  None          DANA HOTEL AND SPA            PORTSMITH/APOGEE    1884390
# 1  None  GORILLA SUSHI LOGAN SQUARE  GORILLA SUSHI LOGAN SQUARE    2543141
# 2  None    PICNIC WINE & PROVISIONS    PICNIC WINE & PROVISIONS    2658904
# 3  None    PICNIC WINE & PROVISIONS    PICNIC WINE & PROVISIONS    2636701
# 4  None    PICNIC WINE & PROVISIONS    PICNIC WINE & PROVISIONS    2636702
#
#          Type             Risk                 Street     City State    Zip  \
# 0  Restaurant    Risk 1 (High)           2 W ERIE ST   CHICAGO    IL  60654
# 1  Restaurant    Risk 1 (High)  2735 N MILWAUKEE AVE   CHICAGO    IL  60647
# 2  Restaurant  Risk 2 (Medium)    7301 N SHERIDAN RD   CHICAGO    IL  60626
# 3  Restaurant  Risk 2 (Medium)    7301 N SHERIDAN RD   CHICAGO    IL  60626
# 4  Restaurant  Risk 2 (Medium)    7301 N SHERIDAN RD   CHICAGO    IL  60626
#
#                   Date             Inspection Success  \
# 0  2019-06-07T00:00:00  Canvass Re-Inspection    Pass
# 1  2019-06-06T00:00:00                Canvass    Fail
# 2  2019-06-06T00:00:00                License    Fail
# 3  2019-06-06T00:00:00                License    Fail
# 4  2019-06-06T00:00:00                License    Fail
#
#                                          Description        Lat        Lng
# 0  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  41.894180 -87.628218
# 1  3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL E...  41.930969 -87.710286
# 2                                               None  42.014041 -87.663971
# 3                                               None  42.014041 -87.663971
# 4                                               None  42.014041 -87.663971

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine

# %%
# Create engine using the `demographics.sqlite` database file
engine = create_engine("sqlite:///ChicagoRestaurants.sqlite")

# %%
########################################################################################################
######################QUERY 1. THIS PULLS ALL DATA AND RETURNS JSONIFIED################################
########################################################################################################
Base = automap_base()
Base.prepare(engine, reflect=True)
Base.classes.keys()
restaurants = Base.classes.RestaurantData
session = Session(engine)
###Query####
Output = []
#Name	DBA	identifier	Type	Risk	Street	City	State	Zip	Date	Inspection	Success	Description	Lat	Lng
for row in session.query(restaurants, restaurants.Name, restaurants.DBA, restaurants.Type,restaurants.Risk,restaurants.Street, restaurants.City, \
                         restaurants.State, restaurants.Zip, restaurants.Date,restaurants.Inspection, restaurants.Success, restaurants.Description, \
                        restaurants.Lat, restaurants.Lng).all():
    Output.append(row)
df = pd.DataFrame(data=Output)
df.to_json(orient='records')
# Out:
# '[{"RestaurantData":null,"Name":"DANA HOTEL AND SPA","DBA":"PORTSMITH\\/APOGEE","Type":"Restaurant","Risk":"Risk 1 (High)","Street":"2 W ERIE ST ","City":"CHICAGO","State":"IL","Zip":"60654","Date":"2019-06-07T00:00:00","Inspection":"Canvass Re-Inspection","Success":"Pass","Description":"10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND ACCESSIBLE - Comments:  MISSING A SPLASH GUARD AT MAIN PREP AREA HAND WASH SINK, TOO CLOSE TO OPEN FOOD AND PREP TABLE CUTTING BOARDS, INSTRUCTED TO INSTALL.","Lat":41.8941804548,"Lng":-87.6282181264},{"RestaurantData":null,"Name":"GORILLA SUSHI LOGAN SQUARE","DBA":"GORILLA SUSHI LOGAN SQUARE","Type":"Restaurant","Risk":"Risk 1 (High)","Street":"2735 N MILWAUKEE AVE ","City":"CHICAGO","State":"IL","Zip":"60647","Date":"2019-06-06T00:00:00","Inspection":"Canvass","Success":"Fail","Description":"3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; KNOWLEDGE, RESPONSIBILITIES AND REPORTING - Comments: OBSERVED NO EMPLOYEES HEALTH POLICIES FOR EMPLOYEES.MUST PROVIDE AND MAINTAIN.(PRIORITY FOUNDATION-NO CITATION ISSUED) | 5. PROCEDURES FOR RESPONDING TO VOMITING AND DIARRHEAL EVENTS - Comments: OBSERVED NO CLEAN-UP POLICY PROCEDURE AND ITEMS FOR VOMITING AND DIARRHEA.MUST PROVIDE AND MAINTAIN.(PRIORITY FOUNDATION-NO CITATION ISSUED) | 8. HANDS CLEAN & PROPERLY WASHED - Comments: OBSERVED POOR HYGIENIC PRACTICIES BY BOTH MALE FOOD HANDLERS.OBSERVED A MALE WIPE HIS PLASTIC GLOVES ON A SOILED TOWEL AND CONTINUED TO HANDLE RAW SUSHI AND THE OTHER WITH PLASTIC GLOVES ON HANDLING RAW SUSHI AND THEN TOUCHING GLASSES ON FACE AND WIPING FOREHEAD THEN GOING BACK TO HANDLING RAW SUSHI AGAIN WITHOUT WASHING HANDS AFTER EVERY POSSIBLE CONTAMINATION.HAD THEM TO WASH HANDS(PRIORITY 7-38-010)  | 10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND ACCESSIBLE - Comments: OBSERVED INADEQUATE HAND WASHING SINKS.OBSERVED NO SOAP AT BOTH FRONT PREP AREA HAND SINK AND REAR PREP AREA\\/DISH WASHING AREA.SOAP WASH PROVIDED DURING INSPECTION.MUST PROVIDE AND MAINTAIN AT ALL TIMES.(PRIORITY FOUNDATION 7-38-030(C) | 10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND ACCESSIBLE - Comments: OBSERVED INADEQUATE HAND WASHING FACILITIES.OBSERVED NO HAND DRYING DEVICE AT FRONT PREP AREA HAND SINK.PAPAER TOWELS WERE PROVIDED DURING INSPECTION.MUST PROVIDE AND MAINTAIN AT ALL TIMES.CONSOLIDATED VIOLATION(PRIORITY FOUNDATION 7-38-030(C) | 21. PROPER HOT HOLDING TEMPERATURES - Comments: OBSERVED IMPROPER TEMPERATURES OF 4LBS. COOKED TEMPURA SHRIMP 75.4F,5LBS. COOKED SWEET POTATOES 78.6F,2LBS. SHREEDED CRAB MEAT 64.0F.ON COUNTER TOP NEAR SMALL FRYER.PRODUCT WAS DISCARDED BY MANAGER.MUST HAVE HOT HOLDING AT 135.0F OR ABOVE.APPX.11LBS.$120.(PRIORITY 7-38-005) | 23. PROPER DATE MARKING AND DISPOSITION - Comments: OBSERVED NO DATE MARKINGS ON TCS READY TO EAT FOODS HELD FOR MORE THAN 24 HOURS INSIDE OF COOLERS.MUST PROVIDE AND MAINTAIN.(PRIORITY FOUNDATION-NO CITATION ISSUED) | 25. CONSUMER ADVISORY PROVIDED FOR RAW\\/UNDERCOOKED FOOD - Comments: OBSERVED NO CONSUMER ADVISORY DISCLOSURE AND REMINDER OF THE RISK OF CONSUMING RAW AND UNDERCOOKED FOODS.MUST PROVIDE AND MAINTAIN.(PRIORITY FOUNDATION-NO CITATION ISSUED) | 36. THERMOMETERS PROVIDED & ACCURATE - Comments: OBSERVED NO PROBE THERMOMETER FOR TAKING FOOD TEMPERATURES.MUST PROVIDE AND MAINTAIN.(PRIORITY FOUNDATION 7-38-005) | 37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER - Comments: MUST LABEL FOOD STORAGE CONTAINERS WHEN FOOD IS NOT IN ORIGINAL PACKAGE. | 39. CONTAMINATION PREVENTED DURING FOOD PREPARATION, STORAGE & DISPLAY - Comments: MUST PROVIDE A BARRIER OR REMOVE PLATES AND CUPS FROM SUSHI COUNTER DIRECT PATH OF CUSTOMERS TO PROTECT FROM CONTAMINATION. | 40. PERSONAL CLEANLINESS - Comments: OBSERVED A FOOD HANDLER NOT WEARING A HAIR RESTRAINT.MUST PROVIDE AND MAINTAIN AT ALL TIMES. | 41. WIPING CLOTHS: PROPERLY USED & STORED - Comments: MUST STORE WIPING CLOTHS INSIDE A SANITIZING SOLUTION WHEN NOT IN USE. | 44. UTENSILS, EQUIPMENT & LINENS: PROPERLY STORED, DRIED, & HAND ...

# %%
########################################################################################################
######################QUERY 2. THIS PULLS ALL DATA BY YEAR################################
########################################################################################################
